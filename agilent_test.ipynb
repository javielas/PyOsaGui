# %%
import pyvisa
import numpy as np

# %%
rm = pyvisa.ResourceManager('@py')
rm.list_resources()
# Out:
# ('ASRL6::INSTR',
#  'ASRL3::INSTR',
#  'ASRL4::INSTR',
#  'ASRL8::INSTR',
#  'ASRL5::INSTR')
